# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("D:\AI And Data Science\QbmrBZ/customers.xlsx")

# %%
data.shape
# Out:
# (100, 6)

# %%
data.head()
# Out:
#    CustomerID      CustomerName                         Email  Gender  Age  \
# 0           1     Emma Anderson     emma.anderson@example.com    Male   50
# 1           2       Sarah Brown       sarah.brown@example.com  Female   37
# 2           3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3           4      David Garcia      david.garcia@example.com    Male   25
# 4           5       Emma Miller       emma.miller@example.com  Female   41
#
#    GeographyID
# 0            2
# 1            4
# 2            6
# 3            8
# 4            4

# %%
data.isna().sum()
# Out:
# CustomerID      0
# CustomerName    0
# Email           0
# Gender          0
# Age             0
# GeographyID     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.Gender.value_counts()
# Out:
# Gender
# Female    54
# Male      46
# Name: count, dtype: int64

# %%
data.Age.min(),data.Age.max(),data.Age.mean()
# Out:
# (18, 69, np.float64(41.99))

# %%
plt.hist(data.Age)
# Out:
# (array([ 8., 14., 10., 13., 13., 10.,  8.,  6., 10.,  8.]),
#  array([18. , 23.1, 28.2, 33.3, 38.4, 43.5, 48.6, 53.7, 58.8, 63.9, 69. ]),
#  <BarContainer object of 10 artists>)

# %%
data.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    42.981481
# Male      40.826087
# Name: Age, dtype: float64

# %%
plt.pie(data.Gender.value_counts(),labels=data.Gender.value_counts().index,autopct="%1.0f%%",startangle=90,radius=1,colors=["green","red"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1d97b8191d0>,
# ...
#  [Text(-1.0913261852070943, -0.1378664479898244, 'Female'),
#   Text(1.0913261402844456, 0.13786680358902448, 'Male')],
#  [Text(-0.5952688282947787, -0.07519988072172239, '54%'),
#   Text(0.5952688037915158, 0.07520007468492244, '46%')])

# %%
data["Age_Category"]=pd.cut(data.Age,bins=[18,30,40,50,60,70],
                           labels=['10-30','50-40',])

# %% [markdown]
# ### 2.Costomers Data Geography

# %%
geography=pd.read_excel("D:\AI And Data Science\QbmrBZ\geography.xlsx")

# %%
geography
# Out:
#    ID       Region       City
# 0   1           UK     London
# 1   2      Germany     Berlin
# 2   3       France      Paris
# 3   4        Spain     Madrid
# 4   5        Italy       Rome
# 5   6  Netherlands  Amsterdam
# 6   7      Belgium   Brussels
# 7   8       Sweden  Stockholm
# 8   9  Switzerland     Zurich
# 9  10      Austria     Vienna
