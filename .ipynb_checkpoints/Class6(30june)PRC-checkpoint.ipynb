# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1 - Customers Data

# %%
customers=pd.read_excel("Data Folder/customers.xlsx")
customers
# Out:
#     CustomerID      CustomerName                         Email  Gender  Age  \
# 0            1     Emma Anderson     emma.anderson@example.com    Male   50
# 1            2       Sarah Brown       sarah.brown@example.com  Female   37
# 2            3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3            4      David Garcia      david.garcia@example.com    Male   25
# 4            5       Emma Miller       emma.miller@example.com  Female   41
# ..         ...               ...                           ...     ...  ...
# 95          96    Emily Gonzalez    emily.gonzalez@example.com  Female   38
# 96          97   Emily Rodriguez   emily.rodriguez@example.com  Female   51
# 97          98       Chris Lopez       chris.lopez@example.com  Female   55
# 98          99   Laura Hernandez   laura.hernandez@example.com    Male   41
# 99         100        Jane Brown        jane.brown@example.com  Female   45
#
#     GeographyID
# 0             2
# 1             4
# ...

# %%
customers.shape
# Out:
# (100, 6)

# %%
customers.head()
# Out:
#    CustomerID      CustomerName                         Email  Gender  Age  \
# 0           1     Emma Anderson     emma.anderson@example.com    Male   50
# 1           2       Sarah Brown       sarah.brown@example.com  Female   37
# 2           3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3           4      David Garcia      david.garcia@example.com    Male   25
# 4           5       Emma Miller       emma.miller@example.com  Female   41
#
#    GeographyID
# 0            2
# 1            4
# 2            6
# 3            8
# 4            4

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    100 non-null    int64
#  1   CustomerName  100 non-null    object
#  2   Email         100 non-null    object
#  3   Gender        100 non-null    object
#  4   Age           100 non-null    int64
#  5   GeographyID   100 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
customers.isna().sum()
# Out:
# CustomerID      0
# CustomerName    0
# Email           0
# Gender          0
# Age             0
# GeographyID     0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.Gender.value_counts()
# Out:
# Gender
# Female    54
# Male      46
# Name: count, dtype: int64

# %%
customers.Age.min(),customers.Age.max(),customers.Age.mean()
# Out:
# (18, 69, np.float64(41.99))

# %%
plt.hist(customers.Age)
# Out:
# (array([ 8., 14., 10., 13., 13., 10.,  8.,  6., 10.,  8.]),
#  array([18. , 23.1, 28.2, 33.3, 38.4, 43.5, 48.6, 53.7, 58.8, 63.9, 69. ]),
#  <BarContainer object of 10 artists>)

# %%
customers.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    42.981481
# Male      40.826087
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(3,2))
plt.hist(customers[customers.Gender=="Male"]["Age"])
plt.show()

# %%
plt.pie(customers.Gender.value_counts(),labels=customers.Gender.value_counts().index,autopct="%1.1f%%",startangle=90,radius=1,colors=["green","red"])
plt.show()

# %%
customers["Age_Category"]=pd.cut(customers.Age,bins=[18,30,40,50,60,70],
                           labels=["18-30","31-40","41-50","51-60","61-70"])
Age_Freq=customers.Age_Category.value_counts()
Age_Freq
# Out:
# Age_Category
# 31-40    24
# 18-30    22
# 41-50    22
# 51-60    16
# 61-70    14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
plt.bar(x=Age_Freq.index,height=Age_Freq.values)
plt.show()

# %% [markdown]
# ### 2.Costomer's Data Geography

# %%
geography=pd.read_excel("Data Folder\geography.xlsx")

# %%
geography.head(3)
# Out:
#    ID   Region    City
# 0   1       UK  London
# 1   2  Germany  Berlin
# 2   3   France   Paris

# %%
customers_updated=pd.merge(customers,geography,how="left",left_on="CustomerID",right_on="ID").drop("ID",axis=1)

# %%
customers_updated.head(3)
# Out:
#    CustomerID      CustomerName                         Email  Gender  Age  \
# 0           1     Emma Anderson     emma.anderson@example.com    Male   50
# 1           2       Sarah Brown       sarah.brown@example.com  Female   37
# 2           3  Robert Hernandez  robert.hernandez@example.com  Female   26
#
#    GeographyID Age_Category   Region    City
# 0            2        41-50       UK  London
# 1            4        31-40  Germany  Berlin
# 2            6        18-30   France   Paris

# %% [markdown]
# ## 3-Products Data

# %%
products = pd.read_excel("Data Folder/products.xlsx")

# %%
products.head()
# Out:
#    ProductID      ProductName Category   Price
# 0          1    Running Shoes   Sports  223.75
# 1          2  Fitness Tracker   Sports  196.68
# 2          3         Yoga Mat   Sports  485.32
# 3          4        Dumbbells   Sports   26.21
# 4          5      Soccer Ball   Sports   41.26

# %%
products.ProductName.unique()
# Out:
# array(['Running Shoes', 'Fitness Tracker', 'Yoga Mat', 'Dumbbells',
#        'Soccer Ball', 'Tennis Racket', 'Basketball', 'Football Helmet',
#        'Baseball Glove', 'Golf Clubs', 'Ski Boots', 'Ice Skates',
#        'Swim Goggles', 'Cycling Helmet', 'Climbing Rope', 'Kayak',
#        'Surfboard', 'Volleyball', 'Hockey Stick', 'Boxing Gloves'],
#       dtype=object)

# %%
products.Category.unique()
# Out:
# array(['Sports'], dtype=object)

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.isna().sum()
# Out:
# ProductID      0
# ProductName    0
# Category       0
# Price          0
# dtype: int64

# %%
products.shape
# Out:
# (20, 4)

# %% [markdown]
# ### 4- Customers Review Data

# %%
review = pd.read_excel("Data Folder\customer_reviews.xlsx")

# %%
review.head(3)
# Out:
#    ReviewID  CustomerID  ProductID ReviewDate  Rating  \
# 0         1          77         18 2023-12-23       3
# 1         2          80         19 2024-12-25       5
# 2         3          50         13 2025-01-26       4
#
#                                 ReviewText
# 0  Average  experience,  nothing  special.
# 1           The  quality  is    top-notch.
# 2  Five  stars  for  the  quick  delivery.

# %%
reviews_updated =pd.merge(review,customers_updated,on="CustomerID",how="left")

reviews_updated =pd.merge(reviews_updated,products,on="ProductID",how="left")

# %%
reviews_updated.head()
# Out:
#    ReviewID  CustomerID  ProductID ReviewDate  Rating  \
# 0         1          77         18 2023-12-23       3
# 1         2          80         19 2024-12-25       5
# 2         3          50         13 2025-01-26       4
# 3         4          78         15 2025-04-21       3
# 4         5          64          2 2023-07-16       3
#
#                                  ReviewText    CustomerName  \
# 0   Average  experience,  nothing  special.     David Lopez
# 1            The  quality  is    top-notch.     Laura Jones
# 2   Five  stars  for  the  quick  delivery.   Olivia Miller
# 3  Good  quality,  but  could  be  cheaper.    Olivia Smith
# 4   Average  experience,  nothing  special.  Sarah Martinez
#
#                         Email  Gender  Age  GeographyID Age_Category Region  \
# 0     david.lopez@example.com    Male   53            4        51-60    NaN
# 1     laura.jones@example.com  Female   25            6        18-30    NaN
# ...

# %%
reviews_updated.drop(["CustomerID","ProductID","Email","GeographyID"],axis=1,inplace=True)

# %%
reviews_updated.head()
# Out:
#    ReviewID ReviewDate  Rating                                ReviewText  \
# 0         1 2023-12-23       3   Average  experience,  nothing  special.
# 1         2 2024-12-25       5            The  quality  is    top-notch.
# 2         3 2025-01-26       4   Five  stars  for  the  quick  delivery.
# 3         4 2025-04-21       3  Good  quality,  but  could  be  cheaper.
# 4         5 2023-07-16       3   Average  experience,  nothing  special.
#
#      CustomerName  Gender  Age Age_Category Region City      ProductName  \
# 0     David Lopez    Male   53        51-60    NaN  NaN       Volleyball
# 1     Laura Jones  Female   25        18-30    NaN  NaN     Hockey Stick
# 2   Olivia Miller    Male   36        31-40    NaN  NaN     Swim Goggles
# 3    Olivia Smith  Female   24        18-30    NaN  NaN    Climbing Rope
# 4  Sarah Martinez  Female   62        61-70    NaN  NaN  Fitness Tracker
#
#   Category   Price
# 0   Sports   42.80
# 1   Sports  173.83
# 2   Sports  145.97
# ...

# %%
review.duplicated().sum()
# Out:
# np.int64(0)

# %%
review.isna().sum()
# Out:
# ReviewID      0
# CustomerID    0
# ProductID     0
# ReviewDate    0
# Rating        0
# ReviewText    0
# dtype: int64

# %% [markdown]
# ## Customers Engagement Data

# %%
engagement=pd.read_excel("Data Folder\engagement_data.xlsx")

# %%
engagement.head()
# Out:
#    EngagementID  ContentID ContentType  Likes EngagementDate  CompaignID  \
# 0             1         39        Blog    190     2023-08-30           1
# 1             2         48        Blog    114     2023-03-28          18
# 2             3         16       video     32     2023-12-08           7
# 3             4         43       Video     17     2025-01-21          19
# 4             5         16  newsletter    306     2024-02-21           6
#
#    ProductID ViewsClickCombined
# 0          9           1883-671
# 1         20           5280-532
# 2         14           1905-204
# 3         20           2766-257
# 4         15          5116-1524

# %%
engagement["Views"]=engagement.ViewsClickCombined.str.split('-').str[0]

# %%
engagement["Click"]=engagement.ViewsClickCombined.str.split("-").str[1]

# %%
engagement.drop("ViewsClickCombined",axis=1,inplace=True)

# %%
engagement.head()
# Out:
#    EngagementID  ContentID ContentType  Likes EngagementDate  CompaignID  \
# 0             1         39        Blog    190     2023-08-30           1
# 1             2         48        Blog    114     2023-03-28          18
# 2             3         16       video     32     2023-12-08           7
# 3             4         43       Video     17     2025-01-21          19
# 4             5         16  newsletter    306     2024-02-21           6
#
#    ProductID Views Click
# 0          9  1883   671
# 1         20  5280   532
# 2         14  1905   204
# 3         20  2766   257
# 4         15  5116  1524

# %%
engagement_updated = pd.merge(engagement,products[["ProductID","ProductName"]],on="ProductID",how="left")

# %%
engagement_updated
# Out:
#       EngagementID  ContentID  ContentType  Likes EngagementDate  CompaignID  \
# 0                1         39         Blog    190     2023-08-30           1
# 1                2         48         Blog    114     2023-03-28          18
# 2                3         16        video     32     2023-12-08           7
# 3                4         43        Video     17     2025-01-21          19
# 4                5         16   newsletter    306     2024-02-21           6
# ...            ...        ...          ...    ...            ...         ...
# 4618          4619         31        Video    270     2023-05-21           3
# 4619          4620         46   newsletter    209     2023-07-17           8
# 4620          4621         10        video     78     2023-05-24          20
# 4621          4622          6  socialmedia     50     2024-04-14          18
# 4622          4623         31         BLOG    133     2023-09-01           2
#
#       ProductID Views Click      ProductName
# ...

# %%
engagement.duplicated().sum()
# Out:
# np.int64(0)

# %%
engagement.isna().sum()
# Out:
# EngagementID      0
# ContentID         0
# ContentType       0
# Likes             0
# EngagementDate    0
# CompaignID        0
# ProductID         0
# Views             2
# Click             2
# dtype: int64

# %% [markdown]
# ## Customer's Journey

# %%
customer_journey_df=pd.read_excel("Data Folder\customer_journey.xlsx")
customer_journey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4011 entries, 0 to 4010
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   JourneyID   4011 non-null   int64
#  1   CustomerID  4011 non-null   int64
#  2   ProductId   4011 non-null   int64
#  3   VisitDate   4011 non-null   datetime64[ns]
#  4   Stage       4011 non-null   object
#  5   Action      4011 non-null   object
#  6   Duration    3398 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 219.5+ KB

# %%
customer_journey_df.head()
# Out:
#    JourneyID  CustomerID  ProductId  VisitDate        Stage    Action  \
# 0          1          64         18 2024-06-10     Checkout  Drop-off
# 1          2          94         11 2025-07-09     Checkout  Drop-off
# 2          3          34          8 2024-06-14  ProductPage      View
# 3          4          33         18 2025-05-28     Checkout  Drop-off
# 4          5          91         10 2023-02-11     Homepage     Click
#
#    Duration
# 0       NaN
# 1       NaN
# 2     235.0
# 3       NaN
# 4     156.0

# %%
customer_journey_df.Stage=customer_journey_df.Stage.str.lower()

# %%
customer_journey_df.Action.unique()
# Out:
# array(['Drop-off', 'View', 'Click', 'Purchase'], dtype=object)

# %%
customer_journey_df.Duration.isna().sum()
# Out:
# np.int64(613)

# %%
customer_journey_df.duplicated().sum()
# Out:
# np.int64(79)

# %%
customer_journey_df[customer_journey_df.duplicated()].sort_values(by="JourneyID")
# Out:
#       JourneyID  CustomerID  ProductId  VisitDate        Stage    Action  \
# 3993         23          58          1 2023-07-05     homepage      View
# 3997         97          92         19 2025-05-26     homepage      View
# 3951        151          79         20 2023-11-04     checkout  Purchase
# 3939        203          44         11 2024-12-28     homepage      View
# 3940        404          30         13 2023-04-22     homepage      View
# ...         ...         ...        ...        ...          ...       ...
# 3967       3781          54          8 2025-04-14     homepage      View
# 3983       3852          99          5 2025-09-07  productpage      View
# 3941       3881          58         18 2024-08-27     checkout  Drop-off
# 3938       3912          99          9 2025-06-13     homepage     Click
# 3957       3930           2          9 2024-09-22     homepage     Click
#
#       Duration
# 3993      48.0
# 3997     203.0
# 3951     298.0
# 3939     230.0
# ...

# %%
customer_journey_df.drop_duplicates(keep="first",inplace=True)

# %%
customer_journey_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
customer_journey_df.isna().sum()
# Out:
# JourneyID       0
# CustomerID      0
# ProductId       0
# VisitDate       0
# Stage           0
# Action          0
# Duration      598
# dtype: int64

# %%
customer_journey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3932 entries, 0 to 3931
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   JourneyID   3932 non-null   int64
#  1   CustomerID  3932 non-null   int64
#  2   ProductId   3932 non-null   int64
#  3   VisitDate   3932 non-null   datetime64[ns]
#  4   Stage       3932 non-null   object
#  5   Action      3932 non-null   object
#  6   Duration    3334 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 245.8+ KB

# %%
#Converting VisitDate to Datetime and Duration to numeric
