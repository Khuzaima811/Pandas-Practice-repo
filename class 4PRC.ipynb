# %%
import pandas as pd

# %%
data=pd.read_csv("car_data.csv")

# %%
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data.shape
# Out:
# (892, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(94)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (798, 6)

# %%
data.name.unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
data.name=data.name.str.split().str[0:3].str.join(" ")

# %%
data
# Out:
#                        name    company  year          Price  kms_driven  \
# 0       Hyundai Santro Xing    Hyundai  2007         80,000  45,000 kms
# 1       Mahindra Jeep CL550   Mahindra  2006       4,25,000      40 kms
# 2        Maruti Suzuki Alto     Maruti  2018  Ask For Price  22,000 kms
# 3         Hyundai Grand i10    Hyundai  2014       3,25,000  28,000 kms
# 4    Ford EcoSport Titanium       Ford  2014       5,75,000  36,000 kms
# ..                      ...        ...   ...            ...         ...
# 887                      Ta       Tara  zest       3,10,000         NaN
# 888            Tata Zest XM       Tata  2018       2,60,000  27,000 kms
# 889      Mahindra Quanto C8   Mahindra  2013       3,90,000  40,000 kms
# 890         Honda Amaze 1.2      Honda  2014       1,80,000      Petrol
# 891      Chevrolet Sail 1.2  Chevrolet  2014       1,60,000      Petrol
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
# ...

# %%
data.year.unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
"150k".isnumeric()
# Out:
# False

# %%
data1 = data[(data.year.str.isnumeric())] #we can also reassign the data variable there but we can create a new variale there

# %% [raw]
#        ######### FOR UPDATING THE EXISTING data FILE  for particular key/column ,############

# %%
#data.year=data["year"][data.year.str.isnumeric()]  #But nan comes instead of not numeric data

# %%
#data.year.isna().sum()

# %%
#data.info()

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 749 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        749 non-null    object
#  1   company     749 non-null    object
#  2   year        749 non-null    object
#  3   Price       749 non-null    object
#  4   kms_driven  748 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: object(6)
# memory usage: 41.0+ KB

# %%
data1.year=data1.year.astype(int)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2136\2964951714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.year=data1.year.astype(int)

# %% [raw]
# Pandas doesn't know whether data1 is
#
# . a completely new DataFrame ✅
# . or just a view of data ⚠️
#
# When you write:
# data1.year = data1.year.astype(int)
# Pandas says:
#
# "Wait! If data1 is only a view of data, should I modify data too? I'm not sure."
#
# So it shows the warning.
# To fixing it we can use the .copy() function

# %%
data1 = data[(data.year.str.isnumeric())].copy()  #.copy() means it is a copy ,not the original data can be changing

# %%
data1.year=data1.year.astype(int)

# %%
data.Price.unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
ask_for_price=data1[data1.Price=="Ask For Price"]

# %%
data1=data1[data1.Price!="Ask For Price"]

# %% [raw]
#               OR

# %%
data1=data1[~(data1.Price=="Ask For Price")]  # ~ means not

# %%
data1.Price=data1.Price.str.replace(',','').astype(int)

# %%
data1
# Out:
#                        name    company  year   Price    kms_driven fuel_type
# 0       Hyundai Santro Xing    Hyundai  2007   80000    45,000 kms    Petrol
# 1       Mahindra Jeep CL550   Mahindra  2006  425000        40 kms    Diesel
# 3         Hyundai Grand i10    Hyundai  2014  325000    28,000 kms    Petrol
# 4    Ford EcoSport Titanium       Ford  2014  575000    36,000 kms    Diesel
# 6                 Ford Figo       Ford  2012  175000    41,000 kms    Diesel
# ..                      ...        ...   ...     ...           ...       ...
# 886    Toyota Corolla Altis     Toyota  2009  300000  1,32,000 kms    Petrol
# 888            Tata Zest XM       Tata  2018  260000    27,000 kms    Diesel
# 889      Mahindra Quanto C8   Mahindra  2013  390000    40,000 kms    Diesel
# 890         Honda Amaze 1.2      Honda  2014  180000        Petrol       NaN
# 891      Chevrolet Sail 1.2  Chevrolet  2014  160000        Petrol       NaN
#
# [727 rows x 6 columns]

# %%
data1=data1[data1.kms_driven!="Petrol"].copy()

# %%
data1
# Out:
#                        name   company  year   Price    kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000    45,000 kms    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000        40 kms    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000    28,000 kms    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000    36,000 kms    Diesel
# 6                 Ford Figo      Ford  2012  175000    41,000 kms    Diesel
# ..                      ...       ...   ...     ...           ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000    50,000 kms    Petrol
# 885          Tata Indica V2      Tata  2009  110000    30,000 kms    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000  1,32,000 kms    Petrol
# 888            Tata Zest XM      Tata  2018  260000    27,000 kms    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000    40,000 kms    Diesel
#
# [725 rows x 6 columns]

# %%
data1.kms_driven=data1.kms_driven.str.replace(",","").str.replace("kms","").astype(int)

# %%
#                              OR

# %%
#data1.kms_driven=data1.kms_driven.str.replace(",","").str.split().str[0].astype(int)

# %%
data1
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [725 rows x 6 columns]

# %%
data1.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
data1[data1.fuel_type.isna()]
# Out:
#                name company  year   Price  kms_driven fuel_type
# 132  Toyota Corolla  Toyota  2009  275000       26000       NaN

# %%
data1.isna().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     1
# dtype: int64

# %%
data1.fuel_type=data1.fuel_type.fillna(data1.fuel_type.mode()[0])

# %%
data1.fuel_type.isna().sum()
# Out:
# np.int64(0)

# %%
data1.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
data1
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [725 rows x 6 columns]

# %%
ask_for_price["Price"]=ask_for_price.Price.replace("Ask For Price",data1.Price.median())  #when we do inplace=True,So the future warning comes ,for we can assign the values
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2136\1282993090.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ask_for_price["Price"]=ask_for_price.Price.replace("Ask For Price",data1.Price.median())  #when we do inplace=True,So the future warning comes ,for we can assign the values

# %%
 ################ IN THE UPPER CODE IT SHOWS WARNNG BECAUSE IN FUTURE VERSIONS WHEN WE CANNOT TYPECAST OUR NUMBERS DATA INTO FLOAT SO IT CAN DO IT AUTOMATICALLY ,FOR SAFE ZONE WE CAN TYPECAST WITH OUR OWN ###############

# %%
ask_for_price["Price"]=ask_for_price.Price.astype(float)

# %%
ask_for_price
# Out:
#                           name     company  year     Price    kms_driven  \
# 2           Maruti Suzuki Alto      Maruti  2018  290000.0    22,000 kms
# 5       Ford EcoSport Titanium        Ford  2015  290000.0    59,000 kms
# 69                   I want to           I  2017  290000.0           NaN
# 138         Maruti Suzuki Alto      Maruti  2018  290000.0    28,028 kms
# 295        Maruti Suzuki Swift      Maruti  2010  290000.0    52,000 kms
# 304            Tata Indica eV2        Tata  2017  290000.0    84,000 kms
# 388         Maruti Suzuki Alto      Maruti  2018  290000.0    24,000 kms
# 449          Maruti Suzuki Zen      Maruti  2011  290000.0    16,000 kms
# 503         Hyundai Xcent Base     Hyundai  2015  290000.0  1,80,000 kms
# 511            Hyundai Xcent S     Hyundai  2015  290000.0    35,000 kms
# 524          Toyota Innova 2.0      Toyota  2009  290000.0    15,574 kms
# 567             Datsun Go Plus      Datsun  2016  290000.0         5 kms
# ...

# %%
data2=pd.concat([data1,ask_for_price]).sample(747)

# %%
data2   # When we see in the data ,So there is the median of price,Replace from ask for price i.e(290000) is pepeating continously,For handling this we can write .sample(747) for aranging them randomly
# Out:
#                        name     company  year      Price kms_driven fuel_type
# 661       Hyundai Grand i10     Hyundai  2016   380000.0      27000    Petrol
# 8    Ford EcoSport Ambiente        Ford  2016   830000.0      24530    Diesel
# 350             Hyundai i10     Hyundai  2012   244999.0      38000    Petrol
# 769         Ford Fusion 1.4        Ford  2007   125000.0      85455    Diesel
# 460    Maruti Suzuki Baleno      Maruti  2016   500000.0      28000    Petrol
# ..                      ...         ...   ...        ...        ...       ...
# 817         Volkswagen Polo  Volkswagen  2013   299999.0      48000    Diesel
# 158          Datsun Redi GO      Datsun  2016   245000.0       7000    Petrol
# 427          Nissan X Trail      Nissan  2019  1200000.0        300    Diesel
# 647       Hyundai Elite i20     Hyundai  2015   500000.0      22000    Petrol
# 88     Toyota Corolla Altis      Toyota  2010   351000.0      38000    Diesel
#
# [747 rows x 6 columns]

# %%
data2.reset_index(drop=True,inplace=True)

# %%
data2
# Out:
#                        name     company  year      Price kms_driven fuel_type
# 0         Hyundai Grand i10     Hyundai  2016   380000.0      27000    Petrol
# 1    Ford EcoSport Ambiente        Ford  2016   830000.0      24530    Diesel
# 2               Hyundai i10     Hyundai  2012   244999.0      38000    Petrol
# 3           Ford Fusion 1.4        Ford  2007   125000.0      85455    Diesel
# 4      Maruti Suzuki Baleno      Maruti  2016   500000.0      28000    Petrol
# ..                      ...         ...   ...        ...        ...       ...
# 742         Volkswagen Polo  Volkswagen  2013   299999.0      48000    Diesel
# 743          Datsun Redi GO      Datsun  2016   245000.0       7000    Petrol
# 744          Nissan X Trail      Nissan  2019  1200000.0        300    Diesel
# 745       Hyundai Elite i20     Hyundai  2015   500000.0      22000    Petrol
# 746    Toyota Corolla Altis      Toyota  2010   351000.0      38000    Diesel
#
# [747 rows x 6 columns]

# %%
data2[data2.company=="Maruti"]["Price"].mean()
# Out:
# np.float64(271795.2047619048)

# %%
data2[(data2.company=="Maruti") & (data2.fuel_type=="Petrol")]["Price"].mean()
# Out:
# np.float64(223353.8)

# %% [markdown]
# ## Descretization And Binning

# %%
data1=pd.read_excel("Bengaluru_House_Data.xlsx")

# %%
data1
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2026-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2026-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
data1.shape
# Out:
# (13320, 9)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
data1.head()
# Out:
#               area_type         availability                  location  \
# 0  Super built-up  Area  2026-12-19 00:00:00  Electronic City Phase II
# 1            Plot  Area        Ready To Move          Chikka Tirupathi
# 2        Built-up  Area        Ready To Move               Uttarahalli
# 3  Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4  Super built-up  Area        Ready To Move                  Kothanur
#
#         size  society total_sqft  bath  balcony   price
# 0      2 BHK   Coomee       1056   2.0      1.0   39.07
# 1  4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2      3 BHK      NaN       1440   2.0      3.0   62.00
# 3      3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4      2 BHK      NaN       1200   2.0      1.0   51.00

# %%
data1.sample(10)
# Out:
#                   area_type   availability               location       size  \
# 5264   Super built-up  Area  Ready To Move      Kodichikkanahalli      3 BHK
# 1846         Built-up  Area  Ready To Move             NRI Layout  2 Bedroom
# 9879         Built-up  Area  Ready To Move     Vishwapriya Layout  5 Bedroom
# 12854        Built-up  Area  Ready To Move            Tumkur Road  4 Bedroom
# 8970   Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# 2261   Super built-up  Area  Ready To Move            Dasarahalli      3 BHK
# 7366             Plot  Area  Ready To Move              Gottigere  4 Bedroom
# 6609         Built-up  Area  Ready To Move         Hennur Gardens      3 BHK
# 5867   Super built-up  Area  Ready To Move         Sarjapur  Road      2 BHK
# 7119         Built-up  Area  Ready To Move              EPIP Zone      3 BHK
#
#        society total_sqft  bath  balcony  price
# 5264   DiamiSa       1560   2.0      2.0   65.0
# ...

# %%
data1.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
emp = pd.DataFrame({'emp_name':['nasir','asad','fahan' ,'noman', 'ali', 'ahmer','ahmed', 'hasan', 'umer', 'jawed', 'fahad' , 'rehan', 'tahir'],
                'country':['pak', 'pak', 'ind', 'usa', 'iran', 'iraq', 'bangla', 'uae', 'uae', 'iraq','iran','usa','pak']})

# %%
country_capital = {'pak':'islambad', 'ind':'dehli','usa':'washington','iran':'tehran', 'iraq':'baghdad', 'uae':'abudhabi','bangla':'dhaka'}

# %%
emp["capital"]=emp.country.map(country_capital)

# %%
emp
# Out:
#    emp_name country     capital
# 0     nasir     pak    islambad
# 1      asad     pak    islambad
# 2     fahan     ind       dehli
# 3     noman     usa  washington
# 4       ali    iran      tehran
# 5     ahmer    iraq     baghdad
# 6     ahmed  bangla       dhaka
# 7     hasan     uae    abudhabi
# 8      umer     uae    abudhabi
# 9     jawed    iraq     baghdad
# 10    fahad    iran      tehran
# 11    rehan     usa  washington
# 12    tahir     pak    islambad
